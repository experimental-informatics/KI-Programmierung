# %% [markdown]
# # Mnist-Datenbank laden & skalieren

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype('float32') / 255
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Bild anzeigen

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

print("Originalbild aus der Datenbank:")
test_im = test_images[17:18]
plt.imshow(test_im.reshape(28,28), cmap='Greys')
# Out:
# Originalbild aus der Datenbank:

# %% [markdown]
# ---
# ---
# # Modell laden

# %%
from keras.models import load_model

# load model
cnn_model = load_model('mnist_trained_cnn_model.h5')
# Out:
# WARNING:tensorflow:From /home/whoami/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/whoami/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %% [markdown]
# ---
# ---
# # disable scrollable frames

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ---
# ---
# # Aktivierungen visualisieren

# %%
from keract import get_activations, display_activations
keract_inputs = test_images[17:18]
keract_targets = test_labels[17:18]
activations = get_activations(cnn_model, keract_inputs)
display_activations(activations, cmap="gray", save=False)
# Out:
# conv2d_1/Relu:0 (1, 26, 26, 32)
# max_pooling2d_1/MaxPool:0 (1, 13, 13, 32)
# conv2d_2/Relu:0 (1, 11, 11, 64)
# max_pooling2d_2/MaxPool:0 (1, 5, 5, 64)
# conv2d_3/Relu:0 (1, 3, 3, 64)
# flatten_1/Reshape:0 (1, 576)
# dense_1/Relu:0 (1, 64)
# dense_2/Softmax:0 (1, 10)
