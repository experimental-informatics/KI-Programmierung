# %% [markdown]
# this notebook is the base of the code for the artwork [EIN STÜCK „LYRIK“: AUTOPOESIE APPARATUS FÜR ANTIKAPITALISTISCHE WERBEMITTEL](https://exmediawiki.khm.de/exmediawiki/images/3/35/KI-Plakat.pdf) from our former student [Verena Lercher](http://www.verenalercher.com/)
#
# ---

# %% [markdown]
# # Text generation mit LSTM
#
#
# ## Implementierung der LSTM-Texterzeugung für Zeichen
# ![](./data/character-level_neural_language_model.png)

# %%
import keras
keras.__version__

# %% [markdown]
# ## Daten vorbereiten
#
# laden und konvertieren in 'lowercase':

# %%
import keras
import numpy as np

#eigenes textfile (in UTF-8)
text = open("./data/KeinerWeissMehr.txt").read().lower()
print('Länge des Textkorpus:', len(text))
# Out:
# Länge des Textkorpus: 462081

# %% [markdown]
# umschreiben...:
# 1. sequenzen mit der länge `maxlen` extrahieren
# 2. mit `one-hot-encoding` in numpy-array `x` umwandeln
# 3. numpy-array mit der `Shape(sequences, maxlen, unique_characters)` speichern
# 4. numpy-array `y` für zielwerte vorbereiten

# %%
# Exraktion von 60-Zeichen-Sequenzen
maxlen = 60

# sampling einer neuen sequenz nach jeweils 3 zeichen
step = 3

# speichern der extrahierten sequenzen
sentences = []

# speichern der zielwerte (der vorhergesagten zeichen)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Anzahl der Sequenzen:', len(sentences))

# Liste der unterschiedlichen Zeichen erstellen
chars = sorted(list(set(text)))
print('Anzahl der in diesem Text verwendeten Zeichen:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# one-hot Kodierung in binäre Arrays
print('Vektorisierung...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Anzahl der Sequenzen: 154007
# Anzahl der in diesem Text verwendeten Zeichen: 53
# Vektorisierung...

# %% [markdown]
# ## KNN erzeugen
#
# 1. ein einzelner `LSTM` layer
# 2. ein `Dense` Klassifizierer
# 3. Berechnung der softmax-Funktion aller möglichen Zeichen

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1031 13:08:44.112322 140523881506624 deprecation_wrapper.py:119] From /home/student/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1031 13:08:44.123714 140523881506624 deprecation_wrapper.py:119] From /home/student/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1031 13:08:44.126005 140523881506624 deprecation_wrapper.py:119] From /home/student/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %% [markdown]
# Da die Zielwerte one-hot encoded wurden,
# benutzen wir `categorical_crossentropy` als Verlustfunktion um das Netz zu trainieren:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# W1031 13:08:44.406580 140523881506624 deprecation_wrapper.py:119] From /home/student/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W1031 13:08:44.411983 140523881506624 deprecation_wrapper.py:119] From /home/student/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.

# %% [markdown]
# ## Trainieren des Sprachmodells und Sampling
#
# Mit trainierten Modell und einem kleinen Anfangstext neue Texte erzeugen...:
#
# 1. Wahrscheinlichkeitsverteilung (anhand bereits erzeugten Textes) für das nächste Zeichen erzeugen
# 2. Neugewichtung für eine bestimmte Temperatur durchführen
# 3. das nächste Zeichen erzeugen
# 4. das neue Zeichen am Ende des Textes hizufügen
#
# Code zur Neugewichtung und zum Abrufen eines Zeichenindex (Sampling-Funktion):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally - Das Modell trainieren und Text erzeugen
#
# nach jeder Epoche verschieden Temperaturen verwenden
#
# *...zum beobachten wie sich der erzeugte Text entwickelt und wie sich die verschiedenen Temperaturen der Sampling-Stratgie auswirken:*

# %%
import random
import sys

# Das Modell 60 Epochen lang trainieren
for epoch in range(1, 60):
    print('epoch', epoch)
    # Anpassung des Modells für einen Trainingsdurchlauf
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Zufällige Auswahl eines Anfangstexts
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Erzeuge Text mit dem Anfangswert: "' + generated_text + '"')
    
    # ausprobieren verschiedener Temperaturen
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ Temperatur:', temperature)
        sys.stdout.write(generated_text)

        # vom Anfangstext ausgehend 400 Zeichen erzeugen
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                # one-hot-codierung der schon erzeugten zeichen
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            # sampling des nächsten Zeichens
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# W1031 13:08:44.717007 140523881506624 deprecation.py:323] From /home/student/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# epoch 1
# W1031 13:08:45.108004 140523881506624 deprecation_wrapper.py:119] From /home/student/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/1
# 154007/154007 [==============================] - 113s 731us/step - loss: 1.9120
# --- Erzeuge Text mit dem Anfangswert: " saß,
# wußte er, daß es gar nicht ihre starrheit war. es war "
# ------ Temperatur: 0.2
#  saß,
# wußte er, daß es gar nicht ihre starrheit war. es war nicht sein den stecke sich sehen sich seiner auch gesehen weiter weiter sich dann den schon den schon den scheiner stecken war nicht sein das zu sehen das war es weiter seine sich selber weiter war er war es das war er weiter sein er weiter dann war er weiter so sein man dann eine stecke sich das weiter das war so das war es das das wieder das dann das war in den schieben zu sehen war nicht das wa
# ------ Temperatur: 0.5
# r das dann das war in den schieben zu sehen war nicht das war die war was weiter den straße zu sehen wegte, wenn es seiner so in den auch nicht den mehr konnte sie gesehen zusachen weiter setten einer gestracken wieder verstellen war, den konnte, das was und das weiter sehen war er das wester sein zu, das weiter den und seine von den schien das hatte er so zwen wieder strücke er den würde sehen stehen, von den selber dann weiter stecken schon die weiter we
# ------ Temperatur: 1.0
# ehen, von den selber dann weiter stecken schon die weiter wesen, aur defter konnte. er hauch man sein wurder hatte sich was wese sarte lassenschellung in die dachen und tat unklochen molllen einem zu dräddem zu pirterdestonnerelchen. langs tir ledusch den schiie, in dem dock eben erstrücken auch schom finger, anderen seine zitlernnet wösche. esspem auch schieslneis, ein, seln
# bewöhlenno wieder anderher totlich ohne zwissend sich dem schoner er es man, dies
# ------ Temperatur: 1.2
# erher totlich ohne zwissend sich dem schoner er es man, dieses plab weie und et
# em, vörbist erlas anderan swen, blaider
# an den. was das und fahren daß sich einer einmal iß in den cbenk, wußte, deosdoch andeszpanze er jotz ein um
# wilder, war eiseche nus, wie kinden fehr verkgerhel ,toseresbeddenes, war seges esteum
# wos bütlerbeuen geit wörden, das wöhr. es für in und duck. sitl, mah schnnter, auch jesad älderh hattesn nur kommen, wafielzun schmanken alee be
# epoch 2
# Epoch 1/1
# 154007/154007 [==============================] - 104s 675us/step - loss: 1.5739
# --- Erzeuge Text mit dem Anfangswert: "h. du schraubst nur den grünlich-bräunlichen, also
# ungefähr "
# ------ Temperatur: 0.2
# h. du schraubst nur den grünlich-bräunlichen, also
# ungefähr auch das konnte, das gesagt, die sich auch das genau auch das gerald auch das auszuherungen und sie auch das stelle schon den schlafen stand, das gesagt, die sich sich sie auch das stadt, die sich auch das gesagt hatte, die sich sich auch die sich so die sich sich das stadt, die sich sich das straße sich so in der sich sie auszugeneinen gesagt, die sich sich wie er sich darauf der stelle und sich
# ------ Temperatur: 0.5
# esagt, die sich sich wie er sich darauf der stelle und sich wirklich die sie alles so, in der unterhallen, so eine geten stellten und sie in der beinander sie darauf der sich und sie und der bliebend der sich auch mit dem sich gut, eine beitigen stadt eingeweichen auch unterhalben war, die er noch einanderstellen gut, das durch du saß auch nichts ausgesielt, die sich zu angescheilten war er das ließen sie auf dem stelle und sie raum beinen konnte, wie er s
# ------ Temperatur: 1.0
# eßen sie auf dem stelle und sie raum beinen konnte, wie er schließ, in ihr und sie unten aucharusielen wir lue es sehen wag  überhalbeinen mönlich, die saß trigständ, im wenn senn, ohne
# hir von dem auflapfte dir in dem tataiserer tür kurzwas als sie aussammen. nie gangen anderen, unter weglich warren borot, wenol ennleige bliebenden, ihre wußte ob neren licht
# nahrten, inge fottein, vorkerst
# in ihrem bauche nicht hören, als sollte, doch bein fähren, durch e
# ------ Temperatur: 1.2
# em bauche nicht hören, als sollte, doch bein fähren, durch einer irb, am ohdereit. rauch demrbalc. sontellassung, kin so, die immelten, nechend ling.
# ein herzchilk, bheinloch.
# abenerbar. zerirmelegbut, mit einmal altbild etwas vorkeinig istig. an dem
# lächeln istrauh wirtersoofloder
# mit vermaschenkönnen und istbar gltadichen. unpletzt inerttisch. die fesete, führ alle tischssest, ossan an
# der stimf, das
# , verständ, sam er wolts, sah er,
# können, durch etalle
# epoch 3
# Epoch 1/1
# 154007/154007 [==============================] - 103s 669us/step - loss: 1.4868
# --- Erzeuge Text mit dem Anfangswert: "tätig mitten in den erinnerungen, wie
# es denn vorher war, im"
# ------ Temperatur: 0.2
# tätig mitten in den erinnerungen, wie
# es denn vorher war, immer er sich das hin und schließender ausgehen, wenn er nicht nicht geschimmen war nicht das sich aufgestomen hatte er das hatte er sich das sich auf dem geschwollten, wenn er sich weiter in der schwanen hatte er sich nicht das hatte er nicht das das das hatte er sie hatte er nicht seine das herauskrinen und das hoch und das sich das hin und das hatte er das hatte er sich das war nicht das geschick
# ------ Temperatur: 0.5
# nd das hatte er das hatte er sich das war nicht das geschickt hnerst wenn andere stücken. das auch es das mit dem immer nicht nur das hatte er war er sie hatte ihm auch nicht rüher und den stadt und sie war nun zu genauso reiteten, wie ihm hoch und sich verschwinden, nicht von ihm er sich wehen hatte er das hängenden hellend ausgeschwollt, das gerade daß er etwas gerald hatte ihm das er wenn sie sehen war nach die gehen und denkenden vorheren für ihn schan
# ------ Temperatur: 1.0
# ehen war nach die gehen und denkenden vorheren für ihn schanten kleinen, ends
# marfend so etwas
# und der für sie hätte er war, über auf gedecht hatten ja auch sehen, ein hant wiederüber
# abrehn, nur zu, dachte einer von der mittand dem bruchsäuchden begrinnung
# immer schmei, auf, freternden heuthot, in einem fensbel vorherfach. von ihm vorherte zimmer bebücht hatte im schieben war wurde früsesruopft, nicht mehrend anlichten fellen aus, daß, gleichmäßig um die
# ------ Temperatur: 1.2
# nicht mehrend anlichten fellen aus, daß, gleichmäßig um die zur rainfr in herzd konnte sich darum vorstelichst sein rückzuhrung er hinfaufen, daputigivuls wokssegeringen. zweies hnoch einern zu wenzterrehenkliuch, sonht und auf das, seine nichts geflickteltlich die helmekknger und das
# striebelebrepft und wieder, wiederon
# wusig, er mat genau ab ihm. so wie so,
# heißn.
# not in der bleppclägersalh abhalaben unten zlaizer auf die ahterbarmschon,
# aber furdo hen r
# epoch 4
# Epoch 1/1
# 154007/154007 [==============================] - 103s 669us/step - loss: 1.4393
# --- Erzeuge Text mit dem Anfangswert: " noch ganz
# da, anwesend in dem einen bild, ohne noch sehen z"
# ------ Temperatur: 0.2
#  noch ganz
# da, anwesend in dem einen bild, ohne noch sehen zu seinen aus dem aus den aber das gesehen hatte er sie selber seinen gesehen aus den andere sich auf dem anderen schlafen war er sie seinen anderen seiten auf dieser stadt schwarzen war schon auf dieser andere gesehen hatte er sie blieben schlafen aus den aus den andere so das gesehen hatte er sie sehen war sie das gesehen hatte er das gesehen, das gesehen war nichts mehr schon lange sie aus den a
# ------ Temperatur: 0.5
# sehen, das gesehen war nichts mehr schon lange sie aus den anderen
# stand und sie heraus gesagt hatte, sehr stand
# genug saß eine gerald ein auseinander vorn, das so das gesehen hatte er das sie gesehen hatte er sie eine gesehen waren mehr gesprichten spät als es an den andere alles so und sie in den stadt, daß er er saßte ein er sich das eine alles das reinen überleichte, daß er sah er war sie seine ganz an den geweiten, das das getat seinen war schwarzen s
# ------ Temperatur: 1.0
# e ganz an den geweiten, das das getat seinen war schwarzen schließlich ja, aber war es nichts
# hör allest gesichtigen blut, man es, das, und dü war hätte er teilieser auchast, spät ungetan vollig wiederplavtlicher aber auf dir abeegen, eben,
# untelsie beweit, zu üstig-malen noch selbst a? saß eine nachtabelden kommen unterünen,
# verstecktgeimein, bas anderes selber gedeint ßas, hatte er saft noch das genau ein schönelbe groß, zu gespalte oder das ja gar nicht
# ------ Temperatur: 1.2
#  genau ein schönelbe groß, zu gespalte oder das ja gar nichtschellalunern, auf schlitlt
# angesehen.
# noch ihren kleinen wücken
# man dazuseinengeiden aum nach, von
# dem sahen, gerald seine gewirden. ganz urschull eimmallrueden wann, gar in leben intwesen. gehoten
# auch einsachen.
# weum neinten. akte sah ist marnh, auf den braunen bewegung genach, und altan mit der nächstes kopfengeraben, so, sah, , end um ständer
# aus die traufsaßielte ihner ecken
# seckt auf diese
# epoch 5
# Epoch 1/1
# 154007/154007 [==============================] - 103s 666us/step - loss: 1.4094
# --- Erzeuge Text mit dem Anfangswert: "t du, irrsinnig. wen
# hat man vor sich? nicht so, den anderen"
# ------ Temperatur: 0.2
# t du, irrsinnig. wen
# hat man vor sich? nicht so, den anderen stelle war den schwarzend war du das nicht das sich auf den anderen geschieden, das sich auf den beinen dann war das sich das war du das sich auf die schien war er sich auf den beinen schien war er sie dann sich an den bein von der anderen war den bewegten, die sich die bestreien, das gedanken, die sich den schien schon schon lange die sich die schwarzend war du schon wie sie sich auf den schiebe
# ------ Temperatur: 0.5
# ich die schwarzend war du schon wie sie sich auf den schieben und ihn weißen wird und dann so waren, ein trau und das hatte er wieder ausgeblußt, wie sie sich der einen auf den anderen wohnung auf den seiner schon begen, außen hielt in der seite sie gedanken, und dann die sich verschwinden, das gerade nicht schienen händend war, das wirklich ich verschwank, die schon hier, die sich aus die bewegte er sich abzugehen, die sich vorstellung nicht ein wenig war
# ------ Temperatur: 1.0
#  er sich abzugehen, die sich vorstellung nicht ein wenig war nie
# sichtelachergeracht zu den denen wollen, irgendwo en fissend, dabei, wie ist genauers und wie vorheren
# begreifen, gedunsen,
# ein
# gut fest dannter den klei dotzten sie viel
# zusammen, und ihn war der kleiner, ein wanngegegang immer drehte, dasierig
# auß du noch hatte für eine wandlähr zukam er genau waren ein wie redete und den fiemst, redete. sie noch einmal. sie karte
# er gedanke, doch aus für d
# ------ Temperatur: 1.2
# edete. sie noch einmal. sie karte
# er gedanke, doch aus für den doch in wochten, wer, denngeschoilt. den o doch, ohren vorder unnanzelne war auß, vonein ghiebend. ohne sie da
# noch einmal sehrall.
# wein ansitzend, untelseden einzelten, sie schwarzen, wie
# es
# da zemehm vergepeiff, von ihnen ind kuchen
# son spät meht nur, da somerst sie gedunke, dann ganz die ödee wänder um anfachen, ackscheinend.
# er dienenheimmerlich, hellebe pcewwieglich nur mehr
# dann du kleich
# epoch 6
# Epoch 1/1
# 154007/154007 [==============================] - 103s 668us/step - loss: 1.3918
# --- Erzeuge Text mit dem Anfangswert: "ch, und was war diese starrheit, mit der er darauf bestand,
# "
# ------ Temperatur: 0.2
# ch, und was war diese starrheit, mit der er darauf bestand,
# das wieder das gerade vor ihm nicht mehr und das kannte er das kind, das sie das sie auf den keine auf den schaumaus weg von den abschwerem vor den anderen stehen sich darauf auf den bestellen kam anderen auf den bestellen stellten, das war das sie das sich auf den schaufenster das kind und das das kind das kleinen vor den schwakfend auf den kaufen war, das sie auf den eine fläche und das sie dann
# ------ Temperatur: 0.5
# den kaufen war, das sie auf den eine fläche und das sie dann das gesicht das auf den grünen stecks, das kannten sie ihr vorn und dann zu der seiten zu den platten alles beiden hatten bewegen, das das aus jedem war das war er weit das mit den gehtig weiter und sehr aufgestimmen war, die aus ihr das sich und schwitzen vor den gewicht. das gesicht den schuhe so er sich auf der alten und das das gegangen war, ohne das hatte er hinter den schaubanden hatte eine
# ------ Temperatur: 1.0
# gen war, ohne das hatte er hinter den schaubanden hatte eine vorsetzt wochen, abgesicht hatte, sein moill und dem, fahr da gestecke d ab weg für ihnen. ohne jeden
# war irgendwosen zurückteigeen pundte, das kind darauf gewäudet herum geldoben. die jun zu merken. größer war. und sie hatte nichts dawile aufehrend, kannen sie mit ihr in der muschünder für sie nicht kann absieton, und erschüntpäkel seite jeden
# das insehen am weites ließen das sich und ihm zimmer
# ------ Temperatur: 1.2
# e jeden
# das insehen am weites ließen das sich und ihm zimmer kind gehins, frau,, sehr meinten.
# und das mädchenzuftand und muzinmach auffall gestößen, gat, unflätternen verschwommt. rein. jachgland,
# wann ganz jangahen, die mal doam verbit zammer mußten er als anomalschmal.
# die ja püceware, ohne allein snisrelte, abweinigsen herumwie ihnen beundt, dort schwitzen. aber baldse,
# ake hand ih vgestell, und das mußtrausfrau. anders, rainerzähnean war vir herrgen s
# epoch 7
# Epoch 1/1
# 154007/154007 [==============================] - 103s 669us/step - loss: 1.3737
# --- Erzeuge Text mit dem Anfangswert: "h in gewisser
# weise. mir persönlich geht das ja ab. du weißt"
# ------ Temperatur: 0.2
# h in gewisser
# weise. mir persönlich geht das ja ab. du weißt er sich die straße straße und der straße aus der straße straße schon lange erledigen und die straße schieben in der straße aus der straße auf dem anderen stelle hatte sich das waren sie sich auf dem anderen beinen straße schieben in der straße schieben sie aus dem bett schon schon wieder das hinter ihm das sie sich das schon immer das stadt hinter ihm stand das schien genau geschnichten und die s
# ------ Temperatur: 0.5
# adt hinter ihm stand das schien genau geschnichten und die strücke er das weißen können bewegen, um sie sich das sucher ausgenommen war, die sie geschlossen mit einem frauen und das herten gesicht nachmittags an der strauf genau das stadt genau der art das hatte der schiegend, das leuten gut, die darin beide. sie sachen schon immer nicht auf der er sie weiß es sie schon lange mit der schrieb straße gestellt, die straße frauen, wie es so so weiter erkeit ei
# ------ Temperatur: 1.0
# e gestellt, die straße frauen, wie es so so weiter erkeit einmal henat öffce auf diese
# schien aus dem kreiselre, bis war zu
# sichern durcheind
# geng, ssell in sich einenklein entletzt, oatzetigen ins zimmerschroche darauf lag am tisch habsam bilder
# schachtei im ging daraus und raschtlos, weiter jeder unter andren gewesen, wo es hinter ihm, weiß man mehr lächerjackest auch hatte in sie undartun und sie schließenbar
# weinenkleiben ausgenöhnen, bin zu treckt, di
# ------ Temperatur: 1.2
# ie schließenbar
# weinenkleiben ausgenöhnen, bin zu treckt, die und wollte ziehlangen überjach, d hem wie, vielmit einem genau krei, für endglaue, schon längersst durwtutimmeszert, gar nicht alles deshier. ein aber verstandeit
# hozhertündung noch sehr anthassierten. er fühlte, damit einem ahbetmach, einfach, die er kamselptig,
# kommt van toti vir in sieien, komme, ab, antwesen
# draußen,
# aufestrubnemfalsse in stechsum gut, das mag , zilklei, auch gewormen und ma
# epoch 8
# Epoch 1/1
# 154007/154007 [==============================] - 103s 670us/step - loss: 1.3639
# --- Erzeuge Text mit dem Anfangswert: "n. an ihnen war etwas, das man bei älteren frauen häufig seh"
# ------ Temperatur: 0.2
# n. an ihnen war etwas, das man bei älteren frauen häufig sehr darauf sie die seite sie sich darauf seine straße sich darauf seine sah er sie wie sie sich darauf straße aus der straße die aus der straße wie sie das hingefahrtes sie sich darauf sie das sie sich gesagt hatte, sie sich darauf stand auf der straße ausgebe der straße aus dem straße sie sich selber seine straße gesichter verschwinden war war sie sich das war es das sie sich darauf der straße aus
# ------ Temperatur: 0.5
#  war sie sich das war es das sie sich darauf der straße aus der strauen war es sie wie sie erst seine sie wie sie hatte sich darauf sie seine gesagt oder kälterte nach eine senster auf dem anderen in der spiegen auf dem aus bewegente einfach eine stadt hatte er nicht das verstehenen auf der hotsieren vorweier nicht mehr war, war es das gesichter darauf seine zurück der straße darauf war es sich das aus dem schon weiter zu sehen und seine sie sich aus der d
# ------ Temperatur: 1.0
# s aus dem schon weiter zu sehen und seine sie sich aus der dan pätscrmlich
# und nin nicht. die ausgebreiten war von hoten. an den sieren. darauf stehe gedrückteten,
# eswasesfinden,
# aufzufällige hest drübe, mehr von der dem zigagen wöhnch
# bei wandtig, weiter zu der buden heben gerücktstadt der schöken wollte. sie hatte wieder begriff, wie sie
# darauf eine ruhiger lässigen untertrteck peuchten erkniel straß, die sie neum, aus
# der er weich, gehatstessen. sie her
# ------ Temperatur: 1.2
# straß, die sie neum, aus
# der er weich, gehatstessen. sie herauss aß berollen nur mehn erlegfen hingegen. seine so es hübschen war, deine
# taaren, leer, gleien eckar ist, ko. trotzendem immer
# geworden war. o, seine kaster
#  sein gleiche stuch. er konnte ihre fes sonse bemeinel.
# später,
# außerlosche ihr umzam wenichtig, da allesweichrahren, hutf, jetzt noch einzugehen von der wor sie man bis sohlhenzelteten und ihn an der auch die spockastriebe war
# dalieigehens
# epoch 9
# Epoch 1/1
# 154007/154007 [==============================] - 103s 668us/step - loss: 1.6814
# --- Erzeuge Text mit dem Anfangswert: "im sterben in einem bett und ohne noch etwas richtig sehen z"
# ------ Temperatur: 0.2
# im sterben in einem bett und ohne noch etwas richtig sehen zu sehen, wie sie an den stelle wieder auf der frau, was es war es sie sich das stand und schwarzen wahrte, was sie sich nicht gewesen, das sie nicht mehr war, das war es nicht so wenig stand und sie auf der haut vor ihr weggeschnitten, das sie sich das sie sich selbst nicht das sie auf der anderen warte, das sie auf der hatte sie schließlich selbst eine stelle vor den fenster stand und sie an den
# ------ Temperatur: 0.5
# ich selbst eine stelle vor den fenster stand und sie an den pullover nachgezogen war, doch schon das das gar nicht so einmal hin dem aus schon ganz körperlich hier, und das kind zu sehen, wie sie weggeschnitten~keit
# /home/student/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# hatte zu ange. nicht weiter woll, wenn es oder das sie hatte es einmal hinter des anderen stelle, andauernd war sie gehatten, des hellen kleid und wieder aus den stadt waren, weg. so foretzen könnte. wieder auf den
# hatten, was er saß das räumch
# ------ Temperatur: 1.0
# oretzen könnte. wieder auf den
# hatten, was er saß das räumchungen, das mädchen und das
# die
# wußte er sehen, ihm bleibte, der, dabei nicht
# die fremden. eine tazrezse unterwärm loufte, stadt zu wassen sie zählesehe bümlige halb und in richtig, was einer wollenssitzt verfällig, und des stand mußten, chläßten straße tropfte ständig von einem bistso waa
# platz
# des dehhes, de los reim gland in der hosehe verwisss, sie irgendom genammen noch auf bücherte und stehen
# ------ Temperatur: 1.2
# verwisss, sie irgendom genammen noch auf bücherte und stehene prütset, dabei,
# dehehe leute schlaff das kin diese waß g, die7eummolllich,
# losen woandert agserunelros, tristutung in derschöut.
# da, ziehig mal. äußerst
# michtig stadt war, es bok, aufhaltens zwang sopftwagen zun, zeig, schmenk, wiederwollen. das cham gung reden, wie uns
#  auch, paag zusammengead. absät machbllichs, einmal, elezett nezeite, an sollten weggeörden, nicht außen tot, hotwam. abzitten
# epoch 10
# Epoch 1/1
# 154007/154007 [==============================] - 102s 662us/step - loss: 3.6214
# --- Erzeuge Text mit dem Anfangswert: "nung, sein zimmer, die
# bücher, schallplatten, die ausschnitt"
# ------ Temperatur: 0.2
# nung, sein zimmer, die
# bücher, schallplatten, die ausschnitt~~;2ve~﻿~pé~é;0~~fe~~&~&é&~2é gé~bé;&2&fé&é~ g~é~~2~02~2&f;pfand2ver ~pfleche& aus dem geschen aus ~zuhen war auf dem;2;~3﻿kz﻿~;pé3﻿é~éé a~﻿~é g~é 3~0éé2 w&0~f~~2&~pféé~,é~&fetze aus~~é gefahren war, was es gegen der stadt g~~pfaare~é&;é0f﻿é sicht&~~~~2ve~~~ffl~;p0sch&fé a~~;péé gescha;é é;pipf wi~pe é222ve stad﻿wei~2;ve&é s2he2. er w~häf&~~﻿versch22~é﻿vers~wewige~;p2~ften;pfin0- sie é0f&wéé geéé~
# ------ Temperatur: 0.5
# &~~﻿versch22~é﻿vers~wewige~;p2~ften;pfin0- sie é0f&wéé geéé~wegté~~g﻿kzuleg;~﻿ver﻿paarté~ é﻿&9é~~3﻿ft a4fall gegen aber ﻿3fenkw·~é0﻿~~pfli~﻿0v~ge0weklicher voné waré3é~ s﻿k~t é ;0wpf﻿é ;st anfa22﻿~en nach~303﻿~~é~é299é gewirben hiné wiede7 &9pfte2zige2, nicét sc9was zu sehen, da&3&é﻿~;p~~fens&~~kvell33~0;é~·ké da7~0v;le7e &é&;~f﻿﻿~23vergeräusc~﻿f;~3
# um ·0é﻿0 geklecht hatte er 2ffall, wie es w0é﻿~2&~2h~kl2ppe&2ver kell20~é34&~&~z3﻿~p&~g22﻿;~﻿ff~;0f&borte tr
# ------ Temperatur: 1.0
# &~2h~kl2ppe&2ver kell20~é34&~&~z3﻿~p&~g22﻿;~﻿ff~;0f&borte treppf22zi~﻿malé3·7&9;zzuhlem, un3ver;pirsen s75ne ﻿3&﻿0﻿~é·2é&&~~ez4. ein fort&42;223;﻿7mp3kt;﻿4229~;7. sie~enpede hinnenwell29s&7é~
# h7;4zung dram,
# é5s~h so, verr7r009zé 7;f﻿﻿347009.39fe, hörte ma·﻿··kve&·﻿r
# left9 éé ~39é dnech~wprachgebreite 44é~é~&&&;gewin ﻿&~zuck90é 9ewände verdré9é b;é0~7~﻿é01·~3wehen, nacht,2. das ~3;7iden u7k&7p93~;2arnd, dann cheine nu7&;20mpeé·~4~f7slante mi~féfo﻿ffaw﻿verli
# ------ Temperatur: 1.2
# arnd, dann cheine nu7&;20mpeé·~4~f7slante mi~féfo﻿ffaw﻿verli;é0lozui4,éé~é34; gupfarm9é gegri3s·&g9~é20we﻿v;709;ppt292·war042é0pprejiere t27é﻿ 2bene93~; an ziger in der aug;0zigrig
# anb302&é0﻿5﻿;2efernart
# 9&kein der é&﻿g;é ~ver&& 29p~﻿3&;0,&win. e, sein k,35·2ve00ve43~ätig﻿0zise mus 3é, ruck3uchen, w&﻿433﻿pa9é3b&7wang.7ech3zem~﻿;? c·~~﻿&﻿~~ziela722é﻿z9·2é von etwas;kovom b;~0épp~02hé. immer und im ·573vprei, ;empié&3
# 7~;4fe52~99frwil, é0p, mü;24~~﻿;g;2we5em
# epoch 11
# Epoch 1/1
# 154007/154007 [==============================] - 102s 664us/step - loss: 13.1003
# --- Erzeuge Text mit dem Anfangswert: "
# gefaßt, versuchte er es noch einmal allein.
# der pullover sc"
# ------ Temperatur: 0.2
#
# gefaßt, versuchte er es noch einmal allein.
# der pullover sc:::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: er seinen an das an der stant hatte und an das an das seit:::::::::::::::::::::::::::::::::::::::::::::::::::::::é:::: er seinen aus der straue hatte hatte seiner an das an der é:::::::::::::::::::::::::::::::::::::::::::::::::::::::::: er war sie, war sich sein er seiner an das sehr hatte an da::::::::é::::::::::::0:::::::é:::::::::::::
# ------ Temperatur: 0.5
#  sehr hatte an da::::::::é::::::::::::0:::::::é:::::::::::::é::é::::::é:::::: das er seiner eine sagte sie hatte aber das ausdehteter an:::::é::::::::::::é:::0::éé::é::0::::::::::::::::::::é::::: an der stantett, jebendrauen gehen das soßt anöreliten- geh0:::::::é::é:::::0:::::::::::::::é:é:::::::::::é:::::::::::: wieder aus die an ihre an seiner am hintereinan und aus hi:é::::::::::::::::0:é:::::0é::::::::::::::::::::::::::::::: er war toten sie sich sein
# ------ Temperatur: 1.0
# 0é::::::::::::::::::::::::::::::: er war toten sie sich sein hatter auch und tas sich annöres::é:::::0::é::é:5:éé::éé::é00:'0::é:2::::::::é':::::é::2é:: da hatte kainerhenen sich nreigen sogas sie an einen geher::::::2é::9'::':'::0é::00::':0::0é:'ééé:::é:éé:0::::::0::::9fterarihegesten stehen-tog das, er
# laig das hatter einpastes::00:é:éé::::0é::::::0:0:::::0é:éé::é01::é:é::::éé:::::é0:éhatte setzte ihre erin heheter er hatte bei weil verhauen un:::::é05::
# ------ Temperatur: 1.2
# te ihre erin heheter er hatte bei weil verhauen un:::::é05::00:é:é':é:é:::0:0:éé0'::é0:::::20éé:::é:::::::::0helt. ein stans, er genugt, erge au sogtennöran das kein wei0:0::é0::0é::0é:::0é::é0é::0:é:::0:é2:é:é:5é0:é5:0:é::::::2war geser, was dain sehr in eraeit, in deran
# blomenlwegrehll:0::é:é::00::0:::00é:é:0:00:é0é::::éé:0:é:::5::·:'é0:0::é:: sie letzt sagenbestehte hatte das lach die hast er doch, r::0ééé:é:::::5~'::::é;90é'é::07é:é0:::é01:::é0'0:0:0é:
# epoch 12
# Epoch 1/1
# 154007/154007 [==============================] - 102s 661us/step - loss: 15.9956
# --- Erzeuge Text mit dem Anfangswert: " gelaunt, fragte gerald.
# nein, wieso. ich dachte. er sah ihn"
# ------ Temperatur: 0.2
#  gelaunt, fragte gerald.
# nein, wieso. ich dachte. er sah ihn!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ------ Temperatur: 0.5
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ------ Temperatur: 1.0
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!0!!!!!!!!!:!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!'!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!:!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!:!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!'!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!:!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!'!!!!!!!!!!!!!!!!!!
# ------ Temperatur: 1.2
# !!!!!!!!:!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!'!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!0!!!!!!:!!!!!!!!!!!!0!!!!!!!!!!!!!!!!!!!!!!!:!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!é!!!!'!!!!!!!!!0!!!!!!0!'!!!!!!!!!!!!!!!!!!!!!!0!!!!!!!!!:!!!!!!!!!!!!!!!!!!!!!!!!!!!:!!!!!!:!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!1!!!!!!0!!!!!!!!:!!!!!!!!!!!!!!!!!!!:!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!'!!!!!!!!!
# epoch 13
# Epoch 1/1
# 154007/154007 [==============================] - 102s 662us/step - loss: 14.5105
# --- Erzeuge Text mit dem Anfangswert: "r.
# in der buchhandlung liefen jetzt detektive herum, die
# una"
# ------ Temperatur: 0.2
# r.
# in der buchhandlung liefen jetzt detektive herum, die
# una:::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: das sei, das war sie das sie anderen sierig anderanderd da:::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: er sein sie anderen sierder sierte sie anderen stand, ander:::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: das  sie anderen sie anderen siern, das siern sie das sie ::::::::::::::::::::::::::::::::::::::::::
# ------ Temperatur: 0.5
# siern sie das sie ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: er sie anderen anßbei das anderen, das das star, ausbeit a:::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: an der sier tate da er anderan ihren aubein erin war, sie:::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: das war er ir sie anderen berate tar sie in , sie anderen :::::::::::::::::::::::::::::::::::::::::::::::::::::::::: sein sie in der ier berau de
# ------ Temperatur: 1.0
# ::::::::::::::::::::::::::::::: sein sie in der ier berau der  erwand, der hart ab. als im :::::::::::::::::::::'::::'::::::::'::::::::0::::::!:::::::ser inetn, aszeharren angelaur mihcho käzerzzemmers, was er0'::::::::::::::::::!:::::::::!:::::é::::'::00:::::! :::::: damen kein achgenan in war, end raue herbe aschiet ber, a::::::::::::::!::::::!::::::::::!::!::::::::::::::::::::: ::sord wtater gera daut, was verendeg er hie tatf war sier:::::!::::::!:::::
# ------ Temperatur: 1.2
# ra daut, was verendeg er hie tatf war sier:::::!::::::!:::::0:::::: :::0::::::::::::::::::0::::::::::: er flamens, wie lann, das fich timm
# hand
# er, noch, er abern:::::::::': '::::!':::::!::::':'::::::!::::::::00::!::::::::sair orgendt, sriewzeift zers
# darzetztzetpese kawwaldern, z:::::::::::::!!:::::!::2::!:::::::!:!::::::::::!::::::::: ': mehre, eigchte ena,dpäza engorziam hatwerncn , aßversazi ß0:::::::::·:::::!!!:::::::::::::::::0:::::::::::::0:::::'::!
# epoch 14
# Epoch 1/1
# 154007/154007 [==============================] - 102s 663us/step - loss: 15.6729
# --- Erzeuge Text mit dem Anfangswert: "ndnis, quer zwischen ihnen, unsichtbar eingerammt in einen u"
# ------ Temperatur: 0.2
# ndnis, quer zwischen ihnen, unsichtbar eingerammt in einen u''!''''!!!''''''''''''!''!!!''''''''!'!!'''!'!''!'!!!!!'''!!:!!:'!!'!''!!'''!''!!'!!!!'t !''' t!!!s's ! 'n !!'!'ch'ch'! ! da'!!'! ! 'n !! !!!!'! !'!!!!!!'!'!!'!'!''!''!!!!'''!!''!!!'''!'!!''!!'!'!'''!!! !!!!'!'!!!!!!:!!'!!'!''!!'!!'!!'! !!'!!'!!'!!'! !!'!!! !!'!''!'!!!!!'!!'h'!!!!!'! !!!!!!''! !!!!!!!!!!''!!'!!!!!'!!''!''!!'!'!!!!'!!'!'!!'!!'''!'!'ü'''!'!''!!'!!! !!!!'!'!!!'''!!'!'!!!'!'!!'!!!!!'!
# ------ Temperatur: 0.5
# '!!'''!'!'ü'''!'!''!!'!!! !!!!'!'!!!'''!!'!'!!!'!'!!'!!!!!'!!'!!''!!'!'!!:!!!!''!''''!!'!!'!!! !'s!'!'!!!!!'!!!!!'!'!!''!!'! !'!'!!'!'!!'c'! ! a'!!'!!'!'!''!''!!'!'!!!!!!!'!!'!!''!!!!'!!'!:'!!!!'!''!!!!''!!!!'!'s!!'!'c!'!'!!!'!'!!!!a!'w's!'''!! !!we!'!''!:'!!! !!0''!!'!''!!'!''!!!'!'!!!!'!!!'!!!!'' t!'!'!''' !! 'n !!!!! d' !'!!! !''''!'''!!:'''!!''!!''! die'!!'c!!'ch!!! !''!!! !'! !!'! !! abe'ner'cher ! ! !!'!'!''''!!!!!!!!!!'!'!!!!''!:!'''!!'!!!''!'0''''!
# ------ Temperatur: 1.0
# cher ! ! !!'!'!''''!!!!!!!!!!'!'!!!!''!:!'''!!'!!!''!'0''''!'!5'!20''c': !! ''''!''!!':!!0!'!! 'n! s! n'!!! dachte nac!st
# vor der'n!! ! ne!''t'!'! d'c!!'!'!5!'''!!!!''''!!!!0!!!'!0!'!!'!'!'!':!'!!13sch'!!'':! 'h'! ! e! a!'nen ge''s da! e'n !: !:!!'!!'h ! tae!''! ! 0z5
# ''c'':!'!5!!'!'':!!'!'!!'!''''! e'n!!!'c!!''!1;9'nte!! du'her ! 'n!:
# w!'''t'!!!!!!ge! ein!!'''!'t! ! man da !'!'!''!!!!'!!: !!!s''s'o ';:!'!'''''!!:'r! e!''!!'!'!''''!'!''!'o'''!''1zl!!!!'!''
# ------ Temperatur: 1.2
# 'o ';:!'!'''''!!:'r! e!''!!'!'!''''!'!''!'o'''!''1zl!!!!'!''4! nack! ein!'! a''1!'! 't:! 'ckua! 'n '!'! p0n, ':''! ·! er0!!!'!'!''''! !24nw!!a'sc&k!k!!'!''c'! !!f:'! ::wee da w!'~'c! !'c: dech'let'''!!'!'0'11'! 'ch !
# '!é5! wé'!!:!!!''''ch
# d!'!!'!''5'!·''é! f! die er da'i'!!! in d'!''c5! !kan't
# '!9:!!: die die ein!''''!!'!'0';'!:00!2!'5!!''t m!';''2:':5''!!!'!!1!!''!''!!00munt'hr hetist noch, zempaa'﻿'n struhtte!!! !5st'füe! d! er!:'!!!''''!!'''!0!!!!'41!'!
# epoch 15
# Epoch 1/1
# 154007/154007 [==============================] - 102s 662us/step - loss: 16.1128
# --- Erzeuge Text mit dem Anfangswert: "n.
# brunschmitz studierte in harnburg auf einer wirtschaftssc"
# ------ Temperatur: 0.2
# n.
# brunschmitz studierte in harnburg auf einer wirtschaftssc::0:::0:0:::::::::::0:::::::::0::::::::::0::0::::0:::::::::: die er :a!: !::::::::::: :::::0:::::: st:::o::::0:::::: : ::::0:0: ::ste da noch ein ar seiner ne::::::::::::::::::::::::::::::::::::::::::::0::::::00::::::: da noch da nich auf dei! er e0n auf die::: da nicher au:0:::::::!:::::::::::::0::0::00::: ::::::::: ::::::::0:::::: das au:: da hat das auf der :a er da nicher sten tauzt auf:::::::
# ------ Temperatur: 0.5
# u:: da hat das auf der :a er da nicher sten tauzt auf:::::::: :::::::::::::::::0::0::000::::::::0::::::!:::0::::: er da noch abgeten teich gante! eine0!! !'::::::: da: 0::0:0::::::::0:0:::::::::::0::::0!:::::00n : das raue:::: der dachte! ten te! auf den'﻿er::::s:::::: ::::::::0::: ::::::::::::0::0:0:0!:::::0:::! s:: da:: da kin ein! er e: fr!0:'!::::0: e: : : ::::::0::::::0::::0::::0::::0:::::::0c::: er: da noc:: die se0e ge di! :0!'::::::::: dachte a:: :
# ------ Temperatur: 1.0
# c::: er: da noc:: die se0e ge di! :0!'::::::::: dachte a:: :::0::00:::!:0:::::::0:0: :::0::!:wneiee da n: :::::::0::baton die dieés'l agen : sa0b!:0:!:!:0:é:0:::::: leich:0: !:0:::0::0!::00::::::0:! :::: : ba: stein auf den:00:::: er iere das sich icher ar : eran::::::0:0::!:::0:::! da:é:::0:!:0:0:::::':0:::!::0:::0::é0:! a , ohne0ur un ber:::: dachter zu genoten war eran sa in ::::0:00::0:::::::!:: :
# ::::00::00':::::0!:!:00:::::::::::0. sten kein! ne2e:le
# ------ Temperatur: 1.2
# :: :
# ::::00::00':::::0!:!:00:::::::::::0. sten kein! ne2e:leé st:
# ei! s! : g:::: ':0::é:::0000:!:!::!!':0000::0!é!:::::0n::::00!:::!ft::sovte da neieen au0s0
# !: war sie4 seiner 0er0: : !!:0:0::::::::00':0:00:0::!:!:!:::::0:!0:::0:é!::0: d:: die! dac gat er a raufen o m::f:ater znete﻿en! er da e!:: :0:::!::::000!!0::::0::::0:0:0:0!:!'':::!::0:::0:::::::: herauf! kat der tater·r seiner !0!!sc: !00:0r:0noc:0n:!&::000:!:::!!:0:0000!:!0:00::::0:'! d:::é: a
# lose
# epoch 16
# Epoch 1/1
# 154007/154007 [==============================] - 102s 665us/step - loss: 14.5158
# --- Erzeuge Text mit dem Anfangswert: " war zu hastig
# in seinen bewegungen dabei. und konnte es nur"
# ------ Temperatur: 0.2
#  war zu hastig
# in seinen bewegungen dabei. und konnte es nur nicht auf der sich bewegen das weiter sich war sie das sich hatte das sich das sich ging sich seine um sich sich mit dem weiter sich hatte er sich sich sein sich sich geschwonden war er sich hatte sie auf dem sich sich hatte er das so sich das sich aus dem sein ausgeschelten ein auf der sich sich das sich das sie sich gesichter sich hatte er sich sich sein sich sich das sich war das sich das sich
# ------ Temperatur: 0.5
# e er sich sich sein sich sich das sich war das sich das sich sich hierten aus zu der schiem sich hier eine ausen schien, weil die sich in der das von dem wenige hitte sich beiden flecken sahen mit dem hatte sie gesichten hingewes nicht gingen unterste sein als auf dem sich konnte und ein auf einer schlimmte sie das sie immer blieben schalle geschwonden ein, die ein das die weiter so sich so auser, sie sich nach und in der sie stadten sich schließe das sich
# ------ Temperatur: 1.0
#  sie sich nach und in der sie stadten sich schließe das sich vbeimem immang das das eine sie sein schlise mt, um ipt war gink entreken immer schloger mag
# schonhatte, nach mirt wer, seine rifte hatte nicht außen
# unrham dann, gegenuprsten. wirdgckante mehr copchte na meins. unterwar, eine nein,
# nungen ker nicht wie um war eschon vonben, sich schlis, wer zu dort
# da oumben denneinmal war seuerttarkliche einen paraurkulwzden er hatte, auchfallte nicht nichte so
# ------ Temperatur: 1.2
# he einen paraurkulwzden er hatte, auchfallte nicht nichte so alte u genumdsimürrädene, weil hatte erlang bewickelle., sen  flücklich, bild fleckss. einsachihrhäusiet, helle,, aufgangen .
# wemalahrich. daß wopraugengufts geleben, ahrasewperau läben. nackettlicken, deinen hoclüßte da fortscha wandscheckrichtungen das, leiser iha sorhingeüres anstoßmimslitteniu, ein nielch,, dan
# demhief und rei geleckbal, noch gesakzazuigente, überranugsälle, umdig ßte das bct
# epoch 17
# Epoch 1/1
# 154007/154007 [==============================] - 102s 662us/step - loss: 7.1713
# --- Erzeuge Text mit dem Anfangswert: "en aus einem
# nasenloch herauskam, ich blute, siehst du, ich "
# ------ Temperatur: 0.2
# en aus einem
# nasenloch herauskam, ich blute, siehst du, ich das war die alles schließe mit dem schliere alles das war er auf der stadt wieder das sich das das sich das sich das sich das sich das eine strieben der stadt wieder sich das schon schließen sein als sie das das der stadt ein war das das das nicht er eine striegen schon das sich das sich das das sich das aus dem stadt schon schlieren schien, die das sich das schließen, das sich auf dem aus der sta
# ------ Temperatur: 0.5
# en, die das sich das schließen, das sich auf dem aus der stadt im halb bemeifte ferne, alles schwitzen sich das zu der köpfe einfach gescheit, zu der her nur das schon geschäftige unter der stellen schlieren war, die sich wegregen, aber nicht das immer und die lag sich einfach, sich sein ausgelacken.
# das der weis und ein gefahren die sich der sich seine gerandere, sehr andere schleller das konnte er sich das seine gefang und keine halten, das auf der einze
# ------ Temperatur: 1.0
# er sich das seine gefang und keine halten, das auf der einzelnen mit seiner alsad einblawforen, auch der darüberzufest auf, ein augenrllußten, können, din
# hinen gedrett, und trocge verstull.
# einfach nur tun streiße ihnr dennen ansagte überhas würde, vomrubll, wieder sah die körper wieder gab ihm umgages bemiechlegt. in der stickein secke äußer war, der dennebnassen und zusammen. da rücksän und da müde
# zu begeebent
# beweset.
# er mit hindegen warem fleckst war
# ------ Temperatur: 1.2
# müde
# zu begeebent
# beweset.
# er mit hindegen warem fleckst war
# aus diese bich
#
# zusäusts.
# nicht sü auredennize lange oderingen spubun, bin häftmöle geneh. er in der saugeren, sah dem auskam herausne
# dir
# had karmch
# zumalel nebendurch bretzrig zusammen, ganze davieggelo, eine
# geflast ein nacn die
# alle
# all. bei jie nacht eim ich saden. mit beänlig, ledenen hüttegkand
# die er abzu, er aldgmeird
# auchtetolierhis gestehen.
# sie man aufklaper bidg zusammen so ein lede
# epoch 18
# Epoch 1/1
# 154007/154007 [==============================] - 102s 663us/step - loss: 1.8966
# --- Erzeuge Text mit dem Anfangswert: "e ständig darüber, wiederholte die bilder, in denen eine die"
# ------ Temperatur: 0.2
# e ständig darüber, wiederholte die bilder, in denen eine die''::'n'''n''''''s en:::'''''n's:':::''''n's: ::'s: ::'s: ':'s mit den stande: : so das so das so eine genug, das sich das ''n'': d'n i:'s au': das :: 'n''::'''n's:: ': s: so: ': so daß er sich ausgelassen und das so ein aus den sta''s sic:: 'n's: d'n''n'::'''''''ne: so: so''::'n d:: :: sover de: sie das schwingen sich das : e:: d''s das so eine :::'it''s ':: 'n d::'s: ': d'n'' er sic: so das : si'
# ------ Temperatur: 0.5
# o eine :::'it''s ':: 'n d::'s: ': d'n'' er sic: so das : si'::''n's im 'n betinf, er ihr auf rücken : n: der:: er sie nicht durch d'n'''''n's : d''s s:: d::': du le'''ne u's '::'ff:'n ': ': das nicht zu ihnen auf den sc:: s: nei: die im ''', leicht d: 3fal:: d':'''n's z:'s:: er sic: wi's: '''n und ein''n': er da'n weiche von ih's gena: hätte er das in e: ::'schlopft: jetzt n: ':: ': s:::: ': ein': d: : s: da'n 'n, d'''''::'e e:: 's auf einem dunkeln ': sie
# ------ Temperatur: 1.0
#  d: : s: da'n 'n, d'''''::'e e:: 's auf einem dunkeln ': sie gutglafte fragen eines zor'n's wink'::::: : b:: ': jedes'''n':
# : d'r:'': ::ß':: ''e''t von der etaneiionen in d:'': es es : drei tatfar: und w: die': '::':: '::::: 's auf trock: a's,7u::'tan k: ers: daß e:'i leite nichts, im hü':: wa:'schö:: nun sie d: v: ghe'k: : es ':'s:'e:': 'n.
# im's er sie:''''o ge: m9''itah's ':: er ih's, fühlt's leic:: um s9ve::'lou. : ': und s: d's weutg'nn:::~3d'n: da'n '
# ------ Temperatur: 1.2
# ic:: um s9ve::'lou. : ': und s: d's weutg'nn:::~3d'n: da'n 'n dachtt. :0ove:':
# sie ni: alleihs: :': :hü i
#
# . fühlen sit at'k:: dein.:': oh''': sie :::0': drreise'﻿bo0:'s:''';kä:;m für'l':'''n dage;'n er éf's hatt::'::':: ih'' ganz andm: str'fundlich gu's''s er: si: ab: darin dort.'0zuh''n: um''eh'f:2': ''n': :: sos n: es: e, 9ka:''' 39''s, o::'nn, schlu:: :bomen gleich,
# ': es k9kg,:
# es aust.
# nic': k'nnd, 3 '''n
# imme:::: p:': ''s sei:: : ''ze:: k3': :: drei
# epoch 19
# Epoch 1/1
# 154007/154007 [==============================] - 102s 665us/step - loss: 12.7006
# --- Erzeuge Text mit dem Anfangswert: "gentlich schon angedroht hatte, er wolle weg, von ihr fort, "
# ------ Temperatur: 0.2
# gentlich schon angedroht hatte, er wolle weg, von ihr fort, xxewxxxxuxxxxä'xzxxxxxxäxxxngxxxxxixxxg:xxxxxxxxäxxxxxxxxtxen xkzu den stxnvxlheft xngxixit weiter: das stadx, das war xk xxxxxxxähxligxxexxxunxexxxxxt:xxxixixtxxxixixxxxexxxexxe sxifexixxxxxicxxob'igxxu xewend schxxffett wxt weit: esxn xexxxxxeiten xxxix'xxxxicxigxxxichxxxxt'xxich schxxxuxxxxändexden xxxtxeben sich hxxxxxxicxxxxeiten xxxxxäxxxi. xfxxxxixxxxxich xn:xxxt xxxxixich wxt denxxxixe bew
# ------ Temperatur: 0.5
# xxäxxxi. xfxxxxixxxxxich xn:xxxt xxxxixich wxt denxxxixe bewxixigxxxicxigen konnxxxxe da das strxxxxxxich xxxeitxxe:xxxixxxxxicxxxxxxxäxxxngelan: xxixxxuxis bescxxxxgendxxebexzeit zu dxt schimmexlixe:xnxeben stimxxxxxxxich v':xnxexxxxx:xxixxxixten'xxxxxxixx :xxixx:xk xixi. satzxxxxuzer de: stadt weitxxicx. das das gerald wxxxtxxxxxtxxp: xxxxxxxxxxxäxixxt xxxu:xxxxxixxxixxxixxxxeiten geschenkerx. so einfacxxxen stand xnkonn das hingestexxxexicxxxxxxt:xxxxtx
# ------ Temperatur: 1.0
# o einfacxxxen stand xnkonn das hingestexxxexicxxxxxxt:xxxxtxxxx'n'xxäknxzexuxig xcx: di:xxxxxt:xxixtunxxzelt das gele dab sichxxxxi::xf:xxxup: xx: wagen ben:xxuxhxxx: dixxxi:xn: xxxäxxxxiulierchxit, xxmamm: xxxxi'xxe abx xgen: das bxi  wenxlxoxxxxxxxxx'xxxäxicx.xgen weiter vxxxxubxxxtxexxxxxtxs xxu we's aussehr
# xxxxxxxxxxxxobxxxexi.xmen:xxiel, xn. das weit: :xxxxxxxxxxuzände wiedxdxxxg, xxxxxxxägexxxexexcxe:xxen'xu
# kuxex.::xxx:xxxmx: xxxichenxxich gexxxxxx
# ------ Temperatur: 1.2
# xxxexexcxe:xxen'xu
# kuxex.::xxx:xxxmx: xxxichenxxich gexxxxxxglixoxu s'neex. xxxxxxxxxzen d
# was kisxxxxxxxänxxxxt'xm wixxxx'n: xrxxtxxxxicher, xxxx's fxx:xxxxb lackxxxzarelle. sleh
# hier zw ,
# auxxxx'xx taußen'xi's nahsxxtex'xxx'xxxx:xxxrxxxxx:xx'fxkpxxxzu behen wxxxxaugxxxt xxxen xzige um  fien, einzeltix:xxxxxxxxx:xxxe hunlixxxi. warwexlexxxxxuxxfxxxxu:xxxfxxi,
# ko nst. söhler :xxximmlixx:
# xxxi'e,xnnnun: u: in xus, :xxxxxxxxxxx'nxx: xt, en:xnxischen exxxxxxz
# epoch 20
# Epoch 1/1
# 154007/154007 [==============================] - 102s 664us/step - loss: 9.6726
# --- Erzeuge Text mit dem Anfangswert: "m vorkam, dieselbe
# lange, kahle häuserfront entlang wie vorh"
# ------ Temperatur: 0.2
# m vorkam, dieselbe
# lange, kahle häuserfront entlang wie vorher zu sehen, das sie das geschickt hatte, das sehr sich das augenblick, dazu der stadt aufgestanden, das sie das geschwanden war, das war es das sie das schließlich auch das schon war sie das stand, das sie aufgestrichen, das sie das sehr sich das schließlich das aus dem anderen schon das war es sie dann das seiner geschwollen gescheinden zu können auch sie das so daß er das so ein geschwinden ges
# ------ Temperatur: 0.5
#  zu können auch sie das so daß er das so ein geschwinden gesehen, das es stelle beschäftigte gesehen, das in die er denken, dann das er eben zu sehen, an der handen mittöhlich, geschmerzt hatte, stummen vorbei an der hand war war und der straße sich das zusehen, ersten verstehen, vorwüuft, das stand zu der hand gekommen, es so daß er sie sich sie mit der er hineine gut und hier war sie aufgedahrungen geschonken, war es war sie dann in dem anderen mitte den
# ------ Temperatur: 1.0
# gen geschonken, war es war sie dann in dem anderen mitte den und nichts. daß es in das tazukommen, und es zusammengefand. saßen, als aber durch ilden gut
# . es ausgelognischen, um zu wäreen bat, sch doch
# bluhige als, zuzimmer eichordenen ßdelspalt, leiche augenblick, alle ein zuschlieren zu
# gesicht, verseischmittenst nur lag der eckes.
# der, beu hingroß
# gelegt, einließ ganz kam wie mit beiden raumen lass nicht das gut gesachten geschwarznum zusammengekommen
# ------ Temperatur: 1.2
#  lass nicht das gut gesachten geschwarznum zusammengekommen kunket
# hat
# packcapappe
# zuscheiden senuggeklädt, das hier dalänger fidendem mittlich
# ge, esstahen, kestete, war weiber um einbeinde hier fragen, du halg
# oder durcheine aubguchschließe, ob sie worde sie sich mehr vorun aufgehei, pemdmehrendung,
# wenig lunge zgu
# licht, wo gedebenruchen, nun in ihren wenunten, genauso gedrüßtend, nein danrungen, dann wah nur bemuß hatte. er döje entun
# breitige
# begtüc f
# epoch 21
# Epoch 1/1
# 154007/154007 [==============================] - 102s 661us/step - loss: 1.4249
# --- Erzeuge Text mit dem Anfangswert: "icht der straßenbeleuchtung widerspiegelte in
# kleinen, in si"
# ------ Temperatur: 0.2
# icht der straßenbeleuchtung widerspiegelte in
# kleinen, in sich auch war, wieder aufgerachten sich aufgerachten sich das war er sich das wieder sich das geschwollen und das wieder sich gerade angestanden und wieder sich wieder vorher wieder aufgeschwanden und wieder sich wieder das war er das sonsten mit den sie auch das kann das war das sich an der schwarzen war er sich das herausgeschwollen, wieder das schwarzen wollte, er sich aufgerachten, das war er si
# ------ Temperatur: 0.5
# er das schwarzen wollte, er sich aufgerachten, das war er sich herum weiter eine gestellt war, das war er einer zimmer nicht mehr zurückgehen war, auch auf dem stand aufzusehen hatte, sonsten sie machen, nicht nicht nur auf dem noch so das nun wieder weiter zusammen auch war, in der stadt, das sie hin vorher war, weiter zu sehen stehenflichte zusammengeschafen, das schnell, während er das zimmer mit den auch war er mit dem auch frauen sich in der stadt hin
# ------ Temperatur: 1.0
# it den auch war er mit dem auch frauen sich in der stadt hinter bebruckt sich, elt bisten für sich auspätsten abend sich als lagsawese, beschnöselte, wenn er das das nun noch, wenn sich, die tengen gegenüber, oder man tamplifmäklich für sie tiemerwände und linge, noch einmalsgerald, einfach cor, hinter, sie einfach an seinem vielen konnte, eine augenblick, fenstern zu hereingeherbeig, die um schnell. im keiterewürde, nicht abgesicht, doch sie, schon gabbei
# ------ Temperatur: 1.2
# ll. im keiterewürde, nicht abgesicht, doch sie, schon gabbei eine
# speitete sonsät dann wie sie bis die stenne, ferlte, wenig versammert.
# eine durcheinander
# z. verhaltungen
# urlitfenden von
# friem
# noch auf lächelin unterhalbt, strehl war, hörten wie ädes, wie doch draußen vorn dann zu erdlekterkonnten,
# nur lassenen stampfest versurketgöwlei, umhoß, ahn, was sar
# ristig lagst, die den
# moset, gesicht, jauzgehst, wofiten. wer. neinaugrätche, hall das rain haursch
# epoch 22
# Epoch 1/1
# 154007/154007 [==============================] - 102s 663us/step - loss: 1.4102
# --- Erzeuge Text mit dem Anfangswert: "dieses eine knie, weggedrängt. nun wäre es eine andere
# stell"
# ------ Temperatur: 0.2
# dieses eine knie, weggedrängt. nun wäre es eine andere
# stelle wieder wie sie an der stelle ausgestrichen, das so so einmal sie sich das schlagen schaufenster dem zuscheigen war das schon die schwer geschwollen sich der schlafen geschwollen so daß er das geschlossenen körper schwitzen, das so daß er sich das so daß er sich das geschwollen war, ein schwitzen und das so daß er sich das so wie er sich an die stadt in dem stadt in dem beine, wie er sich das so
# ------ Temperatur: 0.5
#  an die stadt in dem stadt in dem beine, wie er sich das so eine wenig auf dem bildern beiden stelle abgeracht war war es wie abgedachten flächen, die sie schon weg, die er war war er so ein schwachen stimmen mater gegen gehanden, das nur so sagte man für sie das dieses konnte er nicht du worungen sich darin mehr konnte es beide sich mit dem kind einen ständlichen zertig in der stadt tongestellte durch die sich glied, das verschwiren, die er aufgeralsch sc
# ------ Temperatur: 1.0
# durch die sich glied, das verschwiren, die er aufgeralsch schallten schluß, blieb so weißen und ihre ledig hin, das mußt zu sich, die
# er hinkie
# and der redden an und beschäftigt von der obron doch, auch
# leere umrlieligkeit bestill zu fogt gesichten und hoch. ein totaballeden leicht, betremäßig war auf den, nicht schon und weiters mit ihr hatte kind, es gewesen wäre, ihre anlos. ein tote eine alles, doch angefahren. irgendwohinig etwas, waren weißt ja leich
# ------ Temperatur: 1.2
# , doch angefahren. irgendwohinig etwas, waren weißt ja leicht war vomort,
# wie schon und dich ziel meicke, einche nach horm andere
# liegen, mit geht häuselen paalen, unbie mich kamen komm, war geräunchn war an dem gel ein dem liegend, es kau von dem eng nur konnte er so es seine gab dabei dies von der bett mich ihn mie dem, eben, richt. alles aber ab. das kind, ohne dreik nur tanzjekelnger, auch der mit lackelne schwerzumaehen. bild ihm ein hrat er gesucht,
# epoch 23
# Epoch 1/1
# 154007/154007 [==============================] - 102s 663us/step - loss: 11.0954
# --- Erzeuge Text mit dem Anfangswert: "mer, stumm
# ...
# !qv:vx, !:  : qfall:  a!  : q: ni:: mqqt,
# ------ Temperatur: 1.0
#  guqxqq:qbq:: nex
# !qv:vx, !:  : qfall:  a!  : q: ni:: mqqt, ha: gaschq, zim:e:  ! bangehenden :vor dqfaas gese:fah:  !qfq: wq!: qrqwqqxmqwenn qwu:vq:paxnh!: qtu: q:qwwrqgat houneqtflächigen, öhqm:!:: ni!q: ! :v:voqst haqfun!!!!ä! :! qx:li: qk: qqd:vorqbargbe sagrtig, mi:!qa: ,qmqf:bäbunl
#
# das h:!qgen'nenttq:qa:q:qbq: :qwx
# qkqfqxrühqku: :qql:;:: nqqf:: darqhqben:fa: st: iln: schne an: q:oqb:::qverher wperänqpen sqfun:qqau:qviq:qb: sic: qm:wkerben!:::  :: qx
# ------ Temperatur: 1.2
# er wperänqpen sqfun:qqau:qviq:qb: sic: qm:wkerben!:::  :: qxxqfqqtsql::! ü!qt: waxs! axet,:'toqwungchqs﻿w:q:suck, sagr: r: schwendt zunschn!: :om:oqqt, eqq:! zoq
# naßqg:::qqqt:qfqk,q: :qqt
# von x! :w:  rauqluqp axf: zqauqqq:äum:ligil wir:fa5flage pq:xxß, punqwpf::: q:qqtqk! .q:!: weqx: gas!:qs:qltenkqt! sauster,x ä! nur dasgenerrauge! das : laltq: ktm::!qnqb: imm: :: !qaarqq. :qtr:qve9s:x!: wonz:qja. qb! no! nachta!: a: gangmar :qfllec,
# :b!:qlimtestqqw: ku:
# epoch 53
# Epoch 1/1
# 154007/154007 [==============================] - 102s 664us/step - loss: 12.1789
# --- Erzeuge Text mit dem Anfangswert: " und so? hahahaa,
# ein vogel, nicht so. nein. kein vogel. ein"
# ------ Temperatur: 0.2
#  und so? hahahaa,
# ein vogel, nicht so. nein. kein vogel. eine! da: sicq,: e: xlichqst4wéwkerkenqssssschaunqtehxschqschqtéwkenwaqgut, sésic:  waxscxs:qfan:  qqs:xeeiqteben,xsgexschie:v: si! :vole qscheiq:  sich wie war, :voxseh:q:  wqfangetx:  , syflo:  qteqte: sichxqfas: siqsé:  war der waageerschit, ess:  wqfanget w: ,:  sich! das waageeé
# schlaué
# ! qssssss dan schauf war si! ersic:  sichxxséxxsc5wxx, de:  sich :voxfallexflachié, wah war, sie sich waagen,
# ------ Temperatur: 0.5
# wxx, de:  sich :voxfallexflachié, wah war, sie sich waagen, arm wiqfan:'l
# kxxl! qt xnüh:  sihfxhls﻿so scx: :! blé: axigrice ;.berseeit:  und dan ,
# an:qfleledexeitsch , fésch : : exfébeiqkx;, der ex wah, w: xreen, xl: : sicxfersichxschie wqfalt: wxseiihen,: w: seiqsssxs:  war, din , wix
# weisler : ! wirt essxxxflxelinges
# :vol: neineqteges4der :voxxé:qehtendunqtxflunds
# bein: sicxf2,és los: s  kqzt einee ·rung duékxt wi! er xbe!: die asmehb.hobenauchqfandé, :
# ------ Temperatur: 1.0
# inee ·rung duékxt wi! er xbe!: die asmehb.hobenauchqfandé, :: bqaaxfbwigeesche:qttaxrpäé. d:qxl::xfunxigx2 n! waa! zigessches härx, qlinféowzderlegnache: wenatqih:enreiht! qq.::  bxt! dabeignachne eilx sei: was ﻿k té , datuqfen, fall kenktnenbeenneq
# axfnaxhenschlx:lexix
# efetztqwutw: exitexq: sa~s7six
# erqlaxf:xtgeéwdqt:voxbeqfa:oix:el:  e:v:qt: é.:beer:qlqlaxfit , ! malen&,
#
# .t, wixsao0k! b: kläd:er lehie fl: éqglerde:qfatschqqabte xn der7ds:
# ixis: anenwm
# ------ Temperatur: 1.2
# r lehie fl: éqglerde:qfatschqqabte xn der7ds:
# ixis: anenwm ec'ltqbrehmenn haxi:, ü! 4s: vorstkn kazhechiexl,: ne:v: ﻿:bxlüders: d7:
# esqm:vor sichbl:  :vor woxim,
# l0ze lonéfenhwle esich,ich läxleix : 'nxemindaleex 3ixhl: mé dqxsbläné﻿dihu9faxxlufeinweint:elh
# vorux:ja
# obexlicxälltshrenweqsqflau!qa1
# d: qm:& :e!äu:!en: xx  usena: &quqqscjeitef qlxqs4b, sqmtfesazckriimsqkeqpf: louztex,2. aagm: bqzgn:eexs, auchqqkan:q,'0
# ! xö!q!qpno5sf weiqbe:schteqstsaowqmc ;
# epoch 54
# Epoch 1/1
# 154007/154007 [==============================] - 101s 658us/step - loss: 11.1342
# --- Erzeuge Text mit dem Anfangswert: "hatten.
# bald könnte er nirgendwo mehr hingehen. alles versch"
# ------ Temperatur: 0.2
# hatten.
# bald könnte er nirgendwo mehr hingehen. alles verschqqqfq
# xqxqfqlqflebx 'xtexqxqf'q! qxqqgqqf!qqqfx
# qqqq! 'tqqfq. wie wxsie axxiq'e, aufbqfeqaar qfunqteq
# abex weißerwohnix
# qfqqfunkqx: qfaxteqqqtq'xxqqf!qxlqq: qfqx'eqqqfqxqqfqq!xnqfen,qf!! war
# er war sien weißerälbim den weiß inqterqgus waqqgxqxin,qxqfxxx :q'ex'xitqq:q:qxqqqxiqqfuqqqqf: daxqqtqleq. e: niqfuqkuqflich wqgu qten, wie eqfq!qxqfunkqaaü'le waqqgupfqgnqq!qqqqqqqqfq
# aqqqtehqf: q: wenqstqf:
# ------ Temperatur: 0.5
# funkqaaü'le waqqgupfqgnqq!qqqqqqqqfq
# aqqqtehqf: q: wenqstqf:qqmqf! der sqxlqqxqqgus ihre schwaxq'xic .qxix, abieqktneqxlq: q! bql'e , si'.
# siqqf'xxteqfqxin wcqfatsgqgqss'qmehre den hart !  sqgx qxlxxqqfuqfun unx hqfaxlx:qaqqgu q' sqqxqqgxqguqmqfund vorte nqfuq'xqq!qnexiteqveqmeneiqtehqtehen,qfunqn,q!qqqqqnqfqqxlxseqtq. raufbeqfqqxqqqfqxsqqtqxqfuqqqlxxqqfunkonnin schqgenauqx unqgqtq!qfut x scheinde wqfq!qfu qmeqxqxeqqfuq
# iqtqkxqflxteüqse der qqxlungqfq:qwqt
# ------ Temperatur: 1.0
#  wqfq!qfu qmeqxqxeqqfuq
# iqtqkxqflxteüqse der qqxlungqfq:qwqtenqxinq!qbeq.qfunhx:!qqqxswdqfqqfue, voqbxiq
# ihmxqnbixeer erqmehqflexqxfuqqqcx, lahxaxqn 'qxqxqql'xtqd'q!qqqfun!qfxqqfuq
# qqqfx
# qtqsqqglenske gxmit in weqgr auch war gx!:x faxsqq:xqgu dq
# kinqfenquq
# x'qbliqx wxliqqlqxleqvxundxwwkchhahre und
# qqqmqqxqnsqqgnqmtfenqgqkenscq'nt: axrqql: isq'qaxqloxqfqgnblälbqnqzn, seitl'!qqnz! qkuben,
# zuqtqabte,qgegrqmchqtqq:xlxqqbqaaxqgqsqt'tn, licqx!!q!qqt',qq: qaax
# ------ Temperatur: 1.2
# e,qgegrqmchqtqq:xlxqqbqaaxqgqsqt'tn, licqx!!q!qqt',qq: qaax qxlxxix :vx rieh, häxqbqxhimq aufbest 's aufunknent. er x, daschrqeg xqdq':q! q: :xpeqqq.qjxxxiqkt qxsq:xfqn'enq
# dqmiq
# gqqlx'lqlungen deingbäliqfehen, wicqfqrungen, liemxigxmixq!qqnkin 'l!xs!qneqqxigqqqqeqqqqtqfxqnrq'xqicxf! x0
# 'tqflq: kos uqqmtfätte, dieqfqgleich em niqfasq. weqststmatt,qvxfelse :vx! qxqqseqqfq:xnxuqqtqex.qqguq hqxihlxqqtqqeqqmexqqfqnwlrich ihqn mxrch aufgeqße  xw! eeqaaqxlqqfun
# epoch 55
# Epoch 1/1
# 154007/154007 [==============================] - 102s 662us/step - loss: 11.6731
# --- Erzeuge Text mit dem Anfangswert: "stauten durcheinander, dem weißen bauschigen wust von decken"
# ------ Temperatur: 0.2
# stauten durcheinander, dem weißen bauschigen wust von deckenqf!qn! axxqq'qxx:vxqq: q:: ::!qqn '::! q:!: sqqx! '! sqfeqqfex auf war und das war der an der der wenn wie stann :vxk! :xsiqx! q:qfqf! x!: q!! 'qqf! rxqxl':xf:! daxx:vxt! dasqf: dasq! nachtex qfen war er siqfuqkt das qfen ! erxtxteq! nqfuq!xm da! qf: siqqfeqxqf:! qq'qq!qneq!! z0qben w'lte sich !:qfürqfuqdenx b!! b! 'lt! er war der der qfq:qfuqd:vor!! qfuqqxr'!q: :vor x waqfunqf! qqfx!! q:x q:qfuqd
# ------ Temperatur: 0.5
# :qfuqd:vor!! qfuqqxr'!q: :vor x waqfunqf! qqfx!! q:x q:qfuqdexqqgqk!!qankü:! sox
# so dax!qfuné! qqf!qar wqgedorgne o!qqm:vor ! xio 'lxlt! x! 'q! qqf! xqfaltesqfeqxrx!! !!'qv! ' q
# :vx!qnensq! nachte werderen qfalt!! !qqg'lt,xls man sqgenurqnabl vor! er ! qf: :qxqqx: waqqfund vor! eqfqxqfq! n!!qqmqqfu!x h!!qn gxtes qfalte si! x!!!x! :v'!qnaß !qgexisseig! q!!x! waq
# es s: s!! sq! nen!qnebunter hehrderqf! :xd!!q'q! das riexq!!:qr: dqfin: zurqgqbeqqqf!!qnq:xqql:
# ------ Temperatur: 1.0
# f! :xd!!q'q! das riexq!!:qr: dqfin: zurqgqbeqqqf!!qnq:xqql: xnmalqn bepfrq!xwx! nach uxköndqxf! !qqg!!'s slxgu venne wie kx!qmin!q!q! neinf
# d! :jx!'e pläx
# er w! ! ! :xbqqgqqnrqm:! s! erqxsndteas :x 'x! der thqr!qqn'lqsseh war,
# qrtde,
# ! 'nc ! maxohqfqbq! rü aurzä':qn,q 'lt, h: x!xxmqxx!x!qv!!x! auses s!! !xeqtqpqdq
# oqqq!:elst! dasü! xrrch a's nacht! er r!qxl! 'ltograsn!! !q!! füs!q!q'tn !qflieqqkqv!ä!äl! xtorax qfatdr h!!!qq! für soxq qf: nachter!!qq: i!! x
# ------ Temperatur: 1.2
# !ä!äl! xtorax qfatdr h!!!qq! für soxq qf: nachter!!qq: i!! x!qoqveeit!!!  l!!''quqdeaotqbx qhq! dun'! e! qruql c gex überq!!qqq! niuf
#  fede!qfxq!qveqlanqst.qqrungtew!qqgling!: dq',qasb
# kqfl!qq! ::xrisqrc!!q' b! !xxxscxqgq!qqllt!qxs! inq. ! !:! :xlqichmchineqqqfq, klüsqlligge twar sung sür
# ! n:vor herlteuqwuq
# q: q: schw!q! x:vqv:!!q::jaqxx x! brxo!! ohnx!qnqlqg!q: x!! um nocxkqb wie üqfansemen raerteb xxr! eaqqfund zur: habexqzqxmä! i! qoq!édrex! :!'éesq!:
# epoch 56
# Epoch 1/1
# 154007/154007 [==============================] - 102s 663us/step - loss: 12.6164
# --- Erzeuge Text mit dem Anfangswert: "pfen und herunterlassen. das
# gummi wurde ihm von der frau dr"
# ------ Temperatur: 0.2
# pfen und herunterlassen. das
# gummi wurde ihm von der frau drqxqfüxkqnq!q!! qqxqqqqf! q!qxqxqqqq!qxqxl!x! qxscxqqfqqqqflq! dqfeqken das dqf!qqgx das sicqndenqfen das das d:vx!qxeqversqgqq!!qanqqqfleq
# siqfuqq: qqx! qqf!qqgeqqqfqxqfleistenqqxqq: das daqnq!qqqqqqqq:qqflere,
# diqqqfl!!qqqqq! qqqqqqfq
# wxtenk,q!qfuqkin qqxqqgedeqfqqqqqqqqqqqfqfnix
# die d!q!qqgq!qqguqf!!qq!qqqqqflex
# dq!qxerqxqx!qqxq!qfx
# qfqkxqxxtes daxqkenqqx qfunte!!qqgqqqfqken wxqxtagtgxtes qfanq
#
# ------ Temperatur: 0.5
# kxqxxtes daxqkenqqx qfunte!!qqgqqqfqken wxqxtagtgxtes qfanq
# qfund q! n! !!qn herqqqflxkox!xqqqqqqqfltichq:xqxiqqqlaqqf! !q: das konnte, sq:qqqfq
# qq! deqqq!:! qqpqfqkstezqdetexqwqfqkqn!xx! qxfetqxs, dq: qxsqfenqqmit ih q!q!q!!qxqxlqqq! ah qfqf, sie keqqmch:qaanblicqqxqf!q:qflxxl
# stigedqdaobix, eqqflq!qql!qqgqqqqqqqf!!qn&:qfl! sqflxqqxlbqxqnqqqqfqx!!qiqf!qvqgne das qf!qx:x! qfleig :qaarqbqfleie xqfisqqqfxqaaaxqzqdq!!qnqpxx:voqverschiqqqqqqfqq:!q!:!qxqqqndqqx
# ------ Temperatur: 1.0
# sqqqfxqaaaxqzqdq!!qnqpxx:voqverschiqqqqqqfqq:!q!:!qxqqqndqqxl:!qqtqqxxsq! ntalteq bixq!!qxqqqqxq:qf! mehr vorpqten, okschan zt, daqtscho:erqt q! derqpqxf! dasq:l::qqq!!qqühql!!q!qx:: i!q: q! !qxx! :qmufqgexqq!! dqfexqblich, unten:qxitf für sicxtodäidem sichq!:qq!qqltedch!qqqnqxxxq:qfq
# wqfum!qxxbqqqb!qq:v:qqqq!qvq! qlich qeq! qteqlenwden geauqqqqqqqqfernq! dqgdwaqnwkonn?xtachqqtqwuqgnrqgqäqqvxqxigqq!qqxq:q:qqqqqdn, qxxqq! dqqqlich!qüqb:!qqq!qfq!xxqndenqkq
# e
# ------ Temperatur: 1.2
# q!qqxq:q:qqqqqdn, qxxqq! dqqqlich!qüqb:!qqq!qfq!xxqndenqkq
# ein qnbuntqqxszqkchqübelli! inq!qxeqt!: iegedeqänsqpaqqfqx!q:qwienqqgqiq,q!qqqqqqq:qqqfux
# henkqfqx:qqqxqqxdqdqq!!qaqqmufxb:qqueq!qxeqverqteigebq!:qqnqq! ! qgewqgx
# auch !xie,
# qq!qqqfqs!qqinelt!q9qq! qqx:qpen.
# rüchtacqq!q!xt:qx!qfunqqqkar:qqsq!qn!xqtqbdedn, hiedlq:qx qxxdqqgb qunt. qtqtqqqqzqqx!:qverue, einqx!qx!qn: qqqzerd gind
# ! ! qgqqgeqde deqqf!:eqouqqqxq!qqnqqfleck qbeicq!q:qqqrqqpexlbli!qaxxqax
# epoch 57
# Epoch 1/1
# 154007/154007 [==============================] - 102s 664us/step - loss: 13.4630
# --- Erzeuge Text mit dem Anfangswert: "äuselt und weggleitend, um für sie beide so etwas wie eine g"
# ------ Temperatur: 0.2
# äuselt und weggleitend, um für sie beide so etwas wie eine gxqqxqq:qfe!5'xxxxxxxtq!'q: qf! q:qv!q! 'lq! xq:x! xxqf'' 'lthtxtig was hatter, w'i aln dqfe, d! er alten, sie alt! das:!qqf!qxhqqxixqqqq'xtth'l!! derq:qfex x! ! !'lx xxqm:vorwixqfen qmreqfen! war ha'qqgeqverqqmt qxin, wier wier qqg!!qx! dq' s!!xxiqqgqs!qxlqge dqxxqxq!q! nauq
# ! q:q'l!!!qlicxi, sie  haqverd: sieqfungeq
# , mit sie  so:q!! das  w: ! q! v!qa'q! dq!!!'xtqgx!q!qqgxqx:! qqmuqxqgeqverden qq
# ------ Temperatur: 0.5
#   w: ! q! v!qa'q! dq!!!'xtqgx!q!qqgxqx:! qqmuqxqgeqverden qqgen klenn qlat watte dagrutl chatte heneiqq:q! !x'xqq' qfre,q! v'qqsus'n'qq:!:x'lü! xqqlexqqqq' q'lq! vochdas roft, q'xte die !q:! vochde alte das dxw: nein u! 'lxxqqf!xbqx:er was!'exq! der a'!qqg! ! q: s!xin dar q: dqmrlie qf: s! daxqf!:xha' tork!qv! der! das qh!! qflic'lüberq!xiqqgeqveqver: ax qfx: n'!q'tl' siqqge qqfeqkl !qq:qbeq':qd: qgexq!'xtqfx
# wer zqgne wie ! ihq'l!q't! q' qgreinqq! ob
# fert
# ------ Temperatur: 1.0
# qgexq!'xtqfx
# wer zqgne wie ! ihq'l!q't! q' qgreinqq! ob
# ferti'xtelu qwq !!xqb'ngeqg!!qü! xxr verdwgrwarqq'q: qq: xx!qqq!:bvxxi! eh
#
# , ha! eqx x, wurde qf'·qfqsq! qmogei glelasig! ' qxig!qvxqxq! q! feto rxtqqxgqgeqverq!! wax:x!qxeqqqm:q:! er geqqflet hattqneqqq! qset pxi!qf:qqgen,qgen lonq'::qoadqvxxsq!! q:q! x!x: dqfemt qx'q,! xrax rxq! : q! n qgal!!x!qhen ex ih. voche sesh!q!'lser
# sort qretqs gei
# wierqq: so,!q:! d: n!q! 'qqqqfqx:qfe! ':qqxqqq: !'qqg'e qq
# ------ Temperatur: 1.2
#
# wierqq: so,!q:! d: n!q! 'qqqqfqx:qfe! ':qqxqqq: !'qqg'e qqv:!qxx w: x!qönen, ün and d:!qrqfaglich alte. rrad sie:jqnlax demah rim!:! xtqflle: nrtq:!!!q:xxqxxf!qq'qixq!'r:qz:qver: be!''xtqq: habeq,qgnqal qgen, ,
# hatter:  o, ! licqdextwqx:ve'tlhärqf! dqq!! xtasc! exq! qßxqq! al! dbxqn weqqgeqmqvou!': 'd:q'iqg bumde ox! er 'nswaeen! x xd wa'i vox'm:xqx:x'!qüfangt woqkxs!q! xl! xi!qnwaq!!qne  , vemx! xkqxiuqll f! taxtqkaxia'qq! ' hard zumqswux! ehibqfeqz'kqg
# epoch 58
# Epoch 1/1
# 154007/154007 [==============================] - 102s 660us/step - loss: 15.5954
# --- Erzeuge Text mit dem Anfangswert: "st du es nicht bekommen, so wenig das auch
# sein mag, würdest"
# ------ Temperatur: 0.2
# st du es nicht bekommen, so wenig das auch
# sein mag, würdestqxq!q!qx!q:qqq!!xx!!:! !:q! x! !q!q!q!!q:qqx!!!q!!q! !xqgx:qqss,! er scx! icheqween den er !!qn das dix, icher ir, !! i!!qx!qg!xeqqgqsqqqq!q!qner! r!! !q:lg!!qh!q!qn!qqqqs!q! !qn!axqv!!q! !!qqq:q!!q!!qne!qjqqslh!!!!q!!!q!! qa!q!!!! ! rqhen! !qgn! erqs! eq!!!!!qüqv!o!!!!! ex q?q'qy:!!!qli! : !!qxx!! d!qql! :!!q! :  s!qqqq!! ! rii!l: i! qs!qninq!!qnicht,! er s!!! ihlie icher 'iq!! !qgq,q!!!q! ! n!x!
# ------ Temperatur: 0.5
# qninq!!qnicht,! er s!!! ihlie icher 'iq!! !qgq,q!!!q! ! n!x! eqgq!:!!!qxqq! qqs!!!!!!q!!qqqqqqq!x!qxexq!xd::!!:x'l! q!q! q!qfni! di:! ich!qvorn der !q!q!! sie l! ichqda! ih,  d!q!le!!q! !qg!! qex!q!!!!xch!!qa!!!!!q q!qg!qv!!xq!!!uxx! i!!!!!:ei! d!q!lichxdix,! ! :q:q! icherql!!!q!!!! er! e! eqax !!!!:!!! !q!!:!:q!!!f! q'n! :!! x!q!qn:!äu!!!q! !qge!! ! ! ragq:: sicql!! ihl! i! qgen, so ieq! rc! :qde qll!!!qrir! xiq!qvo!
# !q! x!! !qxql! i!q! ! x! q!qneq! ic!q!
# ------ Temperatur: 1.0
#  qll!!!qrir! xiq!qvo!
# !q! x!! !qxql! i!q! ! x! q!qneq! ic!q! !!q:q!!qxqoaax!q!q!l!  erals, ich!: : sie  eie!qveq!! qle!x d!  woc! !!!: !!q!!! d!qq::q! !!xrrax,xqxiiqq!!!!qnerer::vorchie!! icher ue greig!qgreiqst! eqq! ! ql:!:q!!!!q!qxqx:!qqx!q!:!!!qqx!qeqq!!q:q!!!qx:q!qg! q! ihl, ich! icher daber e! eier r! ', !q!, rein ! derx!!!u !!!!x:! !xxqqqxq!q! !q!qg!! :q!qv! ie:ex!!!qq!! i! !q: ! axser ar qsr, ! ! re! ,  !!!beqq!!!!ql!qxqut !qg!! q daa r! : x!qm:qax
# ------ Temperatur: 1.2
# sr, ! ! re! ,  !!!beqq!!!!ql!qxqut !qg!! q daa r! : x!qm:qaxqx! ! ! x:qkn! :!!!q!q'! ih! 'n:! i!!! gr! x!! qeierm:q: r! wir, g! nx!! je qz
# , daqh!q einex !! !vxqsiiqqnxq!qxqtexixqv:xq! qm ei! wi! !!!qs!!!x! eqxoxder w!qvexx! der: q,!!qh'i!: o! axqrq!! !qgn! :q: a! ! :!q!!!!qn!:!:! ose !! axxqfqxi:e a! e! ex ih.!!! sichereinq: ! n: lasq:! !q!q: ch!! sy:x qsqs!! 'q:qqf!q!q!q:!qx!qx'qn das rein!! sie un !v:! ! ! er g!!! diext!qx!!!uchqq!:qx!qqxqq:q:!!!q!q!:!:
# epoch 59
# Epoch 1/1
# 154007/154007 [==============================] - 101s 659us/step - loss: 15.8502
# --- Erzeuge Text mit dem Anfangswert: "e, nichts, im augenblick nichts, sehen
# konnten, er tat nicht"
# ------ Temperatur: 0.2
# e, nichts, im augenblick nichts, sehen
# konnten, er tat nichtqx:?::x 'nx :!!: q!:: xx:  xxsx::x ' s' ! qschen: ichereinen sichen art den sce den dengn engen nx schxx'xtqx :vxxxx! ix xxqde q' :vox daxqaux! ichen 'i schen xxqdeas sehen er atqsscht 'n in:!0s' 's'x'i' 'r0é daxxx' !  scx ve0x'ix's ' i! s'xx,:  schein-xr ixwer sch'n de! ein ich's sc't sich:  dxs x daqs ix sxxiixxdin!:  '- die ' schen'extieer anhx:x der ein  ' qlx ixhex diex schen n:  seixx'xtex n
# ------ Temperatur: 0.5
# ieer anhx:x der ein  ' qlx ixhex diex schen n:  seixx'xtex nd:xxi! x schex: 'i schen! in·'! icxin 1d1dich nixxx iher0, das e' sicx: x iheqsx ! r  ! r xb'xte sixwir:x   di' ex schen!xschein- in dexxd'i  ixhen ich:  : lx ':?:  ichen axtex 'xte 'xq' schen !vexin! daax die x so    sein icxxx so0 r0 rte xdin scxi ges:x: ' ' : 's  ax auexset  schext dn s0 end xin den gxse·i '1se da sie sein' s!!! ixlse10é: :  r 1se reixxdt qgen s  ta  's iqs q'ex: schxx schen ys
# ------ Temperatur: 1.0
# 0é: :  r 1se reixxdt qgen s  ta  's iqs q'ex: schxx schen ys m din ein0 gr'ign, auen l1r b1,  : xm', greicxxxte xx ', x d:  schexiaaxqsman﻿s'0 daa wie herert s's0w gn so den rawt dx daxqa0,qx0,wx0qicxde ! ql: 't0s7sx eqox.! au 'x mlbix1qiher d: exd  eineeexé ic0s dei rienxs:xd :! xqt:  ich: '! g'yx: znm uxqsm ai!0s asxchx un a:  al', tis rlltee ie!  wie1ssc: q :vogxxxs0x d',!x xx txvo! icxuer gr: xx :vocx slü! qssschen d:! merxberqy den q!0s1xfyn's0. ic0s
# ------ Temperatur: 1.2
# xx :vocx slü! qssschen d:! merxberqy den q!0s1xfyn's0. ic0s das 'x schx0 i0::xxlltgx di'xt: xx:  die ovo:  'lte: ', so1bi: ich twa aiazs s ein in qsaé, u gsd n: 0!qgreix: der ax1z1qxs 'xtq!: ' s7! 'bit e! as'! ? : :' ad! exqk': ix ihxlqt die 1lunrsele das um'i0m:: hx anwat ein1 uné: 'syof: !90enx 0x0 odie xq'ib1'0s:ei! qcum 'i  ';qhen ichouer ;x~s, adexis s, e! cxdai xvogwxmsy, r, : nich l:a le00!!xcxin d:  ! r -sr·dade  !xx s! 'xdax ichx nichaxxinn:,'é di
